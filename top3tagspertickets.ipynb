# %%
# ===============================
# Task 5: Auto Tagging Support Tickets Using LLM
# Zero-Shot + Few-Shot with HuggingFace
# ===============================

# !pip install transformers accelerate datasets -q

import os
import pandas as pd
from transformers import pipeline

# ---------------------------
# Step 1: Load Dataset
# ---------------------------
df = pd.read_csv("customer_support_tickets.csv")
print("Columns in CSV:", df.columns.tolist())

# ---------------------------
# Step 2: Define Candidate Categories
# ---------------------------
candidate_labels = ["Login Issue", "Payment Issue", "Bug", "Feature Request", "Other"]

# ---------------------------
# Step 3: Initialize Zero-Shot Classifier
# ---------------------------
classifier = pipeline(
    "zero-shot-classification",
    model="joeddav/xlm-roberta-large-xnli",  # You can switch to bart-large-mnli for faster runs
    device=0  # Use GPU if available
)

# ---------------------------
# Step 4: Resume if Checkpoint Exists
# ---------------------------
checkpoint_file = "classified_partial.csv"
results = []

if os.path.exists(checkpoint_file):
    print(f"🔄 Resuming from checkpoint: {checkpoint_file}")
    results_df = pd.read_csv(checkpoint_file)
    processed_ids = set(results_df["ticket_id"].tolist())
    results = results_df.to_dict("records")
else:
    processed_ids = set()

# ---------------------------
# Step 5: Prepare Ticket Texts
# ---------------------------
texts = [
    f"{row['Ticket Subject']} - {row['Ticket Description']}"
    for _, row in df.iterrows()
]

# ---------------------------
# Step 6: Zero-Shot (batch all at once)
# ---------------------------
print("⚡ Running Zero-Shot Classification...")
zs_outputs = classifier(texts, candidate_labels, multi_label=True, batch_size=16)

# ---------------------------
# Step 7: Few-Shot Prompts
# ---------------------------
few_shot_prompts = [
    (
        "Example 1:\nTicket: 'I can’t log in to my account.'\nAnswer: Login Issue (0.85), Other (0.15)\n"
        "Example 2:\nTicket: 'My payment failed.'\nAnswer: Payment Issue (0.80), Other (0.20)\n"
        "Example 3:\nTicket: 'App crashes when uploading file.'\nAnswer: Bug (0.75), Feature Request (0.15), Other (0.10)\n"
        f"Now classify this ticket:\nTicket: '{ticket_text}'\nAnswer:"
    )
    for ticket_text in texts
]

print("⚡ Running Few-Shot Classification...")
fs_outputs = classifier(few_shot_prompts, candidate_labels, multi_label=True, batch_size=8)

# ---------------------------
# Step 8: Collect Results
# ---------------------------
for idx, row in df.iterrows():
    if row["Ticket ID"] in processed_ids:
        continue  # Skip already processed tickets

    ticket_text = texts[idx]

    # ---- Zero-Shot ----
    zs = zs_outputs[idx]
    top_idx_zs = sorted(range(len(zs["scores"])), key=lambda i: zs["scores"][i], reverse=True)[:3]
    zs_labels = [zs["labels"][j] for j in top_idx_zs]
    zs_scores = [round(float(zs["scores"][j]), 3) for j in top_idx_zs]

    # ---- Few-Shot ----
    fs = fs_outputs[idx]
    top_idx_fs = sorted(range(len(fs["scores"])), key=lambda i: fs["scores"][i], reverse=True)[:3]
    fs_labels = [fs["labels"][j] for j in top_idx_fs]
    fs_scores = [round(float(fs["scores"][j]), 3) for j in top_idx_fs]

    results.append({
        "ticket_id": row["Ticket ID"],
        "ticket_text": ticket_text,
        "zero_shot_labels": zs_labels,
        "zero_shot_scores": zs_scores,
        "few_shot_labels": fs_labels,
        "few_shot_scores": fs_scores
    })

    if idx % 10 == 0:
        print(f"Processed {idx} tickets...")

    if idx % 500 == 0 and idx > 0:
        # Save checkpoint
        pd.DataFrame(results).to_csv(checkpoint_file, index=False)
        print(f"💾 Saved checkpoint at {idx} tickets")

# ---------------------------
# Step 9: Save Final Results
# ---------------------------
results_df = pd.DataFrame(results)
results_df.to_csv("classified_tickets_results.csv", index=False)
print("✅ Done. Results saved to classified_tickets_results.csv")
# Out:
# Columns in CSV: ['Ticket ID', 'Customer Name', 'Customer Email', 'Customer Age', 'Customer Gender', 'Product Purchased', 'Date of Purchase', 'Ticket Type', 'Ticket Subject', 'Ticket Description', 'Ticket Status', 'Resolution', 'Ticket Priority', 'Ticket Channel', 'First Response Time', 'Time to Resolution', 'Customer Satisfaction Rating']
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/734 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# Some weights of the model checkpoint at joeddav/xlm-roberta-large-xnli were not used when initializing XLMRobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Device set to use cuda:0
# ⚡ Running Zero-Shot Classification...
# ⚡ Running Few-Shot Classification...
# Processed 0 tickets...
# Processed 10 tickets...
# Processed 20 tickets...
# Processed 30 tickets...
# Processed 40 tickets...
# Processed 50 tickets...
# Processed 60 tickets...
# Processed 70 tickets...
# Processed 80 tickets...
# Processed 90 tickets...
# Processed 100 tickets...
# Processed 110 tickets...
# Processed 120 tickets...
# Processed 130 tickets...
# Processed 140 tickets...
# Processed 150 tickets...
# Processed 160 tickets...
# Processed 170 tickets...
# Processed 180 tickets...
# Processed 190 tickets...
# Processed 200 tickets...
# Processed 210 tickets...
# Processed 220 tickets...
# Processed 230 tickets...
# Processed 240 tickets...
# Processed 250 tickets...
# Processed 260 tickets...
# Processed 270 tickets...
# Processed 280 tickets...
# Processed 290 tickets...
# Processed 300 tickets...
# Processed 310 tickets...
# Processed 320 tickets...
# Processed 330 tickets...
# Processed 340 tickets...
# Processed 350 tickets...
# Processed 360 tickets...
# Processed 370 tickets...
# Processed 380 tickets...
# Processed 390 tickets...
# Processed 400 tickets...
# Processed 410 tickets...
# Processed 420 tickets...
# Processed 430 tickets...
# Processed 440 tickets...
# Processed 450 tickets...
# Processed 460 tickets...
# Processed 470 tickets...
# Processed 480 tickets...
# Processed 490 tickets...
# Processed 500 tickets...
# 💾 Saved checkpoint at 500 tickets
# Processed 510 tickets...
# Processed 520 tickets...
# Processed 530 tickets...
# Processed 540 tickets...
# Processed 550 tickets...
# Processed 560 tickets...
# Processed 570 tickets...
# Processed 580 tickets...
# Processed 590 tickets...
# Processed 600 tickets...
# Processed 610 tickets...
# Processed 620 tickets...
# Processed 630 tickets...
# Processed 640 tickets...
# Processed 650 tickets...
# Processed 660 tickets...
# Processed 670 tickets...
# Processed 680 tickets...
# Processed 690 tickets...
# Processed 700 tickets...
# Processed 710 tickets...
# Processed 720 tickets...
# Processed 730 tickets...
# Processed 740 tickets...
# Processed 750 tickets...
# Processed 760 tickets...
# Processed 770 tickets...
# Processed 780 tickets...
# Processed 790 tickets...
# Processed 800 tickets...
# Processed 810 tickets...
# Processed 820 tickets...
# Processed 830 tickets...
# Processed 840 tickets...
# Processed 850 tickets...
# Processed 860 tickets...
# Processed 870 tickets...
# Processed 880 tickets...
# Processed 890 tickets...
# Processed 900 tickets...
# Processed 910 tickets...
# Processed 920 tickets...
# Processed 930 tickets...
# Processed 940 tickets...
# Processed 950 tickets...
# Processed 960 tickets...
# Processed 970 tickets...
# Processed 980 tickets...
# Processed 990 tickets...
# Processed 1000 tickets...
# 💾 Saved checkpoint at 1000 tickets
# Processed 1010 tickets...
# Processed 1020 tickets...
# Processed 1030 tickets...
# Processed 1040 tickets...
# Processed 1050 tickets...
# Processed 1060 tickets...
# Processed 1070 tickets...
# Processed 1080 tickets...
# Processed 1090 tickets...
# Processed 1100 tickets...
# Processed 1110 tickets...
# Processed 1120 tickets...
# Processed 1130 tickets...
# Processed 1140 tickets...
# Processed 1150 tickets...
# Processed 1160 tickets...
# Processed 1170 tickets...
# Processed 1180 tickets...
# Processed 1190 tickets...
# Processed 1200 tickets...
# Processed 1210 tickets...
# Processed 1220 tickets...
# Processed 1230 tickets...
# Processed 1240 tickets...
# Processed 1250 tickets...
# Processed 1260 tickets...
# Processed 1270 tickets...
# Processed 1280 tickets...
# Processed 1290 tickets...
# Processed 1300 tickets...
# Processed 1310 tickets...
# Processed 1320 tickets...
# Processed 1330 tickets...
# Processed 1340 tickets...
# Processed 1350 tickets...
# Processed 1360 tickets...
# Processed 1370 tickets...
# Processed 1380 tickets...
# Processed 1390 tickets...
# Processed 1400 tickets...
# Processed 1410 tickets...
# Processed 1420 tickets...
# Processed 1430 tickets...
# Processed 1440 tickets...
# Processed 1450 tickets...
# Processed 1460 tickets...
# Processed 1470 tickets...
# Processed 1480 tickets...
# Processed 1490 tickets...
# Processed 1500 tickets...
# 💾 Saved checkpoint at 1500 tickets
# Processed 1510 tickets...
# Processed 1520 tickets...
# Processed 1530 tickets...
# Processed 1540 tickets...
# Processed 1550 tickets...
# Processed 1560 tickets...
# Processed 1570 tickets...
# Processed 1580 tickets...
# Processed 1590 tickets...
# Processed 1600 tickets...
# Processed 1610 tickets...
# Processed 1620 tickets...
# Processed 1630 tickets...
# Processed 1640 tickets...
# Processed 1650 tickets...
# Processed 1660 tickets...
# Processed 1670 tickets...
# Processed 1680 tickets...
# Processed 1690 tickets...
# Processed 1700 tickets...
# Processed 1710 tickets...
# Processed 1720 tickets...
# Processed 1730 tickets...
# Processed 1740 tickets...
# Processed 1750 tickets...
# Processed 1760 tickets...
# Processed 1770 tickets...
# Processed 1780 tickets...
# Processed 1790 tickets...
# Processed 1800 tickets...
# Processed 1810 tickets...
# Processed 1820 tickets...
# Processed 1830 tickets...
# Processed 1840 tickets...
# Processed 1850 tickets...
# Processed 1860 tickets...
# Processed 1870 tickets...
# Processed 1880 tickets...
# Processed 1890 tickets...
# Processed 1900 tickets...
# Processed 1910 tickets...
# Processed 1920 tickets...
# Processed 1930 tickets...
# Processed 1940 tickets...
# Processed 1950 tickets...
# Processed 1960 tickets...
# Processed 1970 tickets...
# Processed 1980 tickets...
# Processed 1990 tickets...
# Processed 2000 tickets...
# 💾 Saved checkpoint at 2000 tickets
# Processed 2010 tickets...
# Processed 2020 tickets...
# Processed 2030 tickets...
# Processed 2040 tickets...
# Processed 2050 tickets...
# Processed 2060 tickets...
# Processed 2070 tickets...
# Processed 2080 tickets...
# Processed 2090 tickets...
# Processed 2100 tickets...
# Processed 2110 tickets...
# Processed 2120 tickets...
# Processed 2130 tickets...
# Processed 2140 tickets...
# Processed 2150 tickets...
# Processed 2160 tickets...
# Processed 2170 tickets...
# Processed 2180 tickets...
# Processed 2190 tickets...
# Processed 2200 tickets...
# Processed 2210 tickets...
# Processed 2220 tickets...
# Processed 2230 tickets...
# Processed 2240 tickets...
# Processed 2250 tickets...
# Processed 2260 tickets...
# Processed 2270 tickets...
# Processed 2280 tickets...
# Processed 2290 tickets...
# Processed 2300 tickets...
# Processed 2310 tickets...
# Processed 2320 tickets...
# Processed 2330 tickets...
# Processed 2340 tickets...
# Processed 2350 tickets...
# Processed 2360 tickets...
# Processed 2370 tickets...
# Processed 2380 tickets...
# Processed 2390 tickets...
# Processed 2400 tickets...
# Processed 2410 tickets...
# Processed 2420 tickets...
# Processed 2430 tickets...
# Processed 2440 tickets...
# Processed 2450 tickets...
# Processed 2460 tickets...
# Processed 2470 tickets...
# Processed 2480 tickets...
# Processed 2490 tickets...
# Processed 2500 tickets...
# 💾 Saved checkpoint at 2500 tickets
# Processed 2510 tickets...
# Processed 2520 tickets...
# Processed 2530 tickets...
# Processed 2540 tickets...
# Processed 2550 tickets...
# Processed 2560 tickets...
# Processed 2570 tickets...
# Processed 2580 tickets...
# Processed 2590 tickets...
# Processed 2600 tickets...
# Processed 2610 tickets...
# Processed 2620 tickets...
# Processed 2630 tickets...
# Processed 2640 tickets...
# Processed 2650 tickets...
# Processed 2660 tickets...
# Processed 2670 tickets...
# Processed 2680 tickets...
# Processed 2690 tickets...
# Processed 2700 tickets...
# Processed 2710 tickets...
# Processed 2720 tickets...
# Processed 2730 tickets...
# Processed 2740 tickets...
# Processed 2750 tickets...
# Processed 2760 tickets...
# Processed 2770 tickets...
# Processed 2780 tickets...
# Processed 2790 tickets...
# Processed 2800 tickets...
# Processed 2810 tickets...
# Processed 2820 tickets...
# Processed 2830 tickets...
# Processed 2840 tickets...
# Processed 2850 tickets...
# Processed 2860 tickets...
# Processed 2870 tickets...
# Processed 2880 tickets...
# Processed 2890 tickets...
# Processed 2900 tickets...
# Processed 2910 tickets...
# Processed 2920 tickets...
# Processed 2930 tickets...
# Processed 2940 tickets...
# Processed 2950 tickets...
# Processed 2960 tickets...
# Processed 2970 tickets...
# Processed 2980 tickets...
# Processed 2990 tickets...
# Processed 3000 tickets...
# 💾 Saved checkpoint at 3000 tickets
# Processed 3010 tickets...
# Processed 3020 tickets...
# Processed 3030 tickets...
# Processed 3040 tickets...
# Processed 3050 tickets...
# Processed 3060 tickets...
# Processed 3070 tickets...
# Processed 3080 tickets...
# Processed 3090 tickets...
# Processed 3100 tickets...
# Processed 3110 tickets...
# Processed 3120 tickets...
# Processed 3130 tickets...
# Processed 3140 tickets...
# Processed 3150 tickets...
# Processed 3160 tickets...
# Processed 3170 tickets...
# Processed 3180 tickets...
# Processed 3190 tickets...
# Processed 3200 tickets...
# Processed 3210 tickets...
# Processed 3220 tickets...
# Processed 3230 tickets...
# Processed 3240 tickets...
# Processed 3250 tickets...
# Processed 3260 tickets...
# Processed 3270 tickets...
# Processed 3280 tickets...
# Processed 3290 tickets...
# Processed 3300 tickets...
# Processed 3310 tickets...
# Processed 3320 tickets...
# Processed 3330 tickets...
# Processed 3340 tickets...
# Processed 3350 tickets...
# Processed 3360 tickets...
# Processed 3370 tickets...
# Processed 3380 tickets...
# Processed 3390 tickets...
# Processed 3400 tickets...
# Processed 3410 tickets...
# Processed 3420 tickets...
# Processed 3430 tickets...
# Processed 3440 tickets...
# Processed 3450 tickets...
# Processed 3460 tickets...
# Processed 3470 tickets...
# Processed 3480 tickets...
# Processed 3490 tickets...
# Processed 3500 tickets...
# 💾 Saved checkpoint at 3500 tickets
# Processed 3510 tickets...
# Processed 3520 tickets...
# Processed 3530 tickets...
# Processed 3540 tickets...
# Processed 3550 tickets...
# Processed 3560 tickets...
# Processed 3570 tickets...
# Processed 3580 tickets...
# Processed 3590 tickets...
# Processed 3600 tickets...
# Processed 3610 tickets...
# Processed 3620 tickets...
# Processed 3630 tickets...
# Processed 3640 tickets...
# Processed 3650 tickets...
# Processed 3660 tickets...
# Processed 3670 tickets...
# Processed 3680 tickets...
# Processed 3690 tickets...
# Processed 3700 tickets...
# Processed 3710 tickets...
# Processed 3720 tickets...
# Processed 3730 tickets...
# Processed 3740 tickets...
# Processed 3750 tickets...
# Processed 3760 tickets...
# Processed 3770 tickets...
# Processed 3780 tickets...
# Processed 3790 tickets...
# Processed 3800 tickets...
# Processed 3810 tickets...
# Processed 3820 tickets...
# Processed 3830 tickets...
# Processed 3840 tickets...
# Processed 3850 tickets...
# Processed 3860 tickets...
# Processed 3870 tickets...
# Processed 3880 tickets...
# Processed 3890 tickets...
# Processed 3900 tickets...
# Processed 3910 tickets...
# Processed 3920 tickets...
# Processed 3930 tickets...
# Processed 3940 tickets...
# Processed 3950 tickets...
# Processed 3960 tickets...
# Processed 3970 tickets...
# Processed 3980 tickets...
# Processed 3990 tickets...
# Processed 4000 tickets...
# 💾 Saved checkpoint at 4000 tickets
# Processed 4010 tickets...
# Processed 4020 tickets...
# Processed 4030 tickets...
# Processed 4040 tickets...
# Processed 4050 tickets...
# Processed 4060 tickets...
# Processed 4070 tickets...
# Processed 4080 tickets...
# Processed 4090 tickets...
# Processed 4100 tickets...
# Processed 4110 tickets...
# Processed 4120 tickets...
# Processed 4130 tickets...
# Processed 4140 tickets...
# Processed 4150 tickets...
# Processed 4160 tickets...
# Processed 4170 tickets...
# Processed 4180 tickets...
# Processed 4190 tickets...
# Processed 4200 tickets...
# Processed 4210 tickets...
# Processed 4220 tickets...
# Processed 4230 tickets...
# Processed 4240 tickets...
# Processed 4250 tickets...
# Processed 4260 tickets...
# Processed 4270 tickets...
# Processed 4280 tickets...
# Processed 4290 tickets...
# Processed 4300 tickets...
# Processed 4310 tickets...
# Processed 4320 tickets...
# Processed 4330 tickets...
# Processed 4340 tickets...
# Processed 4350 tickets...
# Processed 4360 tickets...
# Processed 4370 tickets...
# Processed 4380 tickets...
# Processed 4390 tickets...
# Processed 4400 tickets...
# Processed 4410 tickets...
# Processed 4420 tickets...
# Processed 4430 tickets...
# Processed 4440 tickets...
# Processed 4450 tickets...
# Processed 4460 tickets...
# Processed 4470 tickets...
# Processed 4480 tickets...
# Processed 4490 tickets...
# Processed 4500 tickets...
# 💾 Saved checkpoint at 4500 tickets
# Processed 4510 tickets...
# Processed 4520 tickets...
# Processed 4530 tickets...
# Processed 4540 tickets...
# Processed 4550 tickets...
# Processed 4560 tickets...
# Processed 4570 tickets...
# Processed 4580 tickets...
# Processed 4590 tickets...
# Processed 4600 tickets...
# Processed 4610 tickets...
# Processed 4620 tickets...
# Processed 4630 tickets...
# Processed 4640 tickets...
# Processed 4650 tickets...
# Processed 4660 tickets...
# Processed 4670 tickets...
# Processed 4680 tickets...
# Processed 4690 tickets...
# Processed 4700 tickets...
# Processed 4710 tickets...
# Processed 4720 tickets...
# Processed 4730 tickets...
# Processed 4740 tickets...
# Processed 4750 tickets...
# Processed 4760 tickets...
# Processed 4770 tickets...
# Processed 4780 tickets...
# Processed 4790 tickets...
# Processed 4800 tickets...
# Processed 4810 tickets...
# Processed 4820 tickets...
# Processed 4830 tickets...
# Processed 4840 tickets...
# Processed 4850 tickets...
# Processed 4860 tickets...
# Processed 4870 tickets...
# Processed 4880 tickets...
# Processed 4890 tickets...
# Processed 4900 tickets...
# Processed 4910 tickets...
# Processed 4920 tickets...
# Processed 4930 tickets...
# Processed 4940 tickets...
# Processed 4950 tickets...
# Processed 4960 tickets...
# Processed 4970 tickets...
# Processed 4980 tickets...
# Processed 4990 tickets...
# Processed 5000 tickets...
# 💾 Saved checkpoint at 5000 tickets
# Processed 5010 tickets...
# Processed 5020 tickets...
# Processed 5030 tickets...
# Processed 5040 tickets...
# Processed 5050 tickets...
# Processed 5060 tickets...
# Processed 5070 tickets...
# Processed 5080 tickets...
# Processed 5090 tickets...
# Processed 5100 tickets...
# Processed 5110 tickets...
# Processed 5120 tickets...
# Processed 5130 tickets...
# Processed 5140 tickets...
# Processed 5150 tickets...
# Processed 5160 tickets...
# Processed 5170 tickets...
# Processed 5180 tickets...
# Processed 5190 tickets...
# Processed 5200 tickets...
# Processed 5210 tickets...
# Processed 5220 tickets...
# Processed 5230 tickets...
# Processed 5240 tickets...
# Processed 5250 tickets...
# Processed 5260 tickets...
# Processed 5270 tickets...
# Processed 5280 tickets...
# Processed 5290 tickets...
# Processed 5300 tickets...
# Processed 5310 tickets...
# Processed 5320 tickets...
# Processed 5330 tickets...
# Processed 5340 tickets...
# Processed 5350 tickets...
# Processed 5360 tickets...
# Processed 5370 tickets...
# Processed 5380 tickets...
# Processed 5390 tickets...
# Processed 5400 tickets...
# Processed 5410 tickets...
# Processed 5420 tickets...
# Processed 5430 tickets...
# Processed 5440 tickets...
# Processed 5450 tickets...
# Processed 5460 tickets...
# Processed 5470 tickets...
# Processed 5480 tickets...
# Processed 5490 tickets...
# Processed 5500 tickets...
# 💾 Saved checkpoint at 5500 tickets
# Processed 5510 tickets...
# Processed 5520 tickets...
# Processed 5530 tickets...
# Processed 5540 tickets...
# Processed 5550 tickets...
# Processed 5560 tickets...
# Processed 5570 tickets...
# Processed 5580 tickets...
# Processed 5590 tickets...
# Processed 5600 tickets...
# Processed 5610 tickets...
# Processed 5620 tickets...
# Processed 5630 tickets...
# Processed 5640 tickets...
# Processed 5650 tickets...
# Processed 5660 tickets...
# Processed 5670 tickets...
# Processed 5680 tickets...
# Processed 5690 tickets...
# Processed 5700 tickets...
# Processed 5710 tickets...
# Processed 5720 tickets...
# Processed 5730 tickets...
# Processed 5740 tickets...
# Processed 5750 tickets...
# Processed 5760 tickets...
# Processed 5770 tickets...
# Processed 5780 tickets...
# Processed 5790 tickets...
# Processed 5800 tickets...
# Processed 5810 tickets...
# Processed 5820 tickets...
# Processed 5830 tickets...
# Processed 5840 tickets...
# Processed 5850 tickets...
# Processed 5860 tickets...
# Processed 5870 tickets...
# Processed 5880 tickets...
# Processed 5890 tickets...
# Processed 5900 tickets...
# Processed 5910 tickets...
# Processed 5920 tickets...
# Processed 5930 tickets...
# Processed 5940 tickets...
# Processed 5950 tickets...
# Processed 5960 tickets...
# Processed 5970 tickets...
# Processed 5980 tickets...
# Processed 5990 tickets...
# Processed 6000 tickets...
# 💾 Saved checkpoint at 6000 tickets
# Processed 6010 tickets...
# Processed 6020 tickets...
# Processed 6030 tickets...
# Processed 6040 tickets...
# Processed 6050 tickets...
# Processed 6060 tickets...
# Processed 6070 tickets...
# Processed 6080 tickets...
# Processed 6090 tickets...
# Processed 6100 tickets...
# Processed 6110 tickets...
# Processed 6120 tickets...
# Processed 6130 tickets...
# Processed 6140 tickets...
# Processed 6150 tickets...
# Processed 6160 tickets...
# Processed 6170 tickets...
# Processed 6180 tickets...
# Processed 6190 tickets...
# Processed 6200 tickets...
# Processed 6210 tickets...
# Processed 6220 tickets...
# Processed 6230 tickets...
# Processed 6240 tickets...
# Processed 6250 tickets...
# Processed 6260 tickets...
# Processed 6270 tickets...
# Processed 6280 tickets...
# Processed 6290 tickets...
# Processed 6300 tickets...
# Processed 6310 tickets...
# Processed 6320 tickets...
# Processed 6330 tickets...
# Processed 6340 tickets...
# Processed 6350 tickets...
# Processed 6360 tickets...
# Processed 6370 tickets...
# Processed 6380 tickets...
# Processed 6390 tickets...
# Processed 6400 tickets...
# Processed 6410 tickets...
# Processed 6420 tickets...
# Processed 6430 tickets...
# Processed 6440 tickets...
# Processed 6450 tickets...
# Processed 6460 tickets...
# Processed 6470 tickets...
# Processed 6480 tickets...
# Processed 6490 tickets...
# Processed 6500 tickets...
# 💾 Saved checkpoint at 6500 tickets
# Processed 6510 tickets...
# Processed 6520 tickets...
# Processed 6530 tickets...
# Processed 6540 tickets...
# Processed 6550 tickets...
# Processed 6560 tickets...
# Processed 6570 tickets...
# Processed 6580 tickets...
# Processed 6590 tickets...
# Processed 6600 tickets...
# Processed 6610 tickets...
# Processed 6620 tickets...
# Processed 6630 tickets...
# Processed 6640 tickets...
# Processed 6650 tickets...
# Processed 6660 tickets...
# Processed 6670 tickets...
# Processed 6680 tickets...
# Processed 6690 tickets...
# Processed 6700 tickets...
# Processed 6710 tickets...
# Processed 6720 tickets...
# Processed 6730 tickets...
# Processed 6740 tickets...
# Processed 6750 tickets...
# Processed 6760 tickets...
# Processed 6770 tickets...
# Processed 6780 tickets...
# Processed 6790 tickets...
# Processed 6800 tickets...
# Processed 6810 tickets...
# Processed 6820 tickets...
# Processed 6830 tickets...
# Processed 6840 tickets...
# Processed 6850 tickets...
# Processed 6860 tickets...
# Processed 6870 tickets...
# Processed 6880 tickets...
# Processed 6890 tickets...
# Processed 6900 tickets...
# Processed 6910 tickets...
# Processed 6920 tickets...
# Processed 6930 tickets...
# Processed 6940 tickets...
# Processed 6950 tickets...
# Processed 6960 tickets...
# Processed 6970 tickets...
# Processed 6980 tickets...
# Processed 6990 tickets...
# Processed 7000 tickets...
# 💾 Saved checkpoint at 7000 tickets
# Processed 7010 tickets...
# Processed 7020 tickets...
# Processed 7030 tickets...
# Processed 7040 tickets...
# Processed 7050 tickets...
# Processed 7060 tickets...
# Processed 7070 tickets...
# Processed 7080 tickets...
# Processed 7090 tickets...
# Processed 7100 tickets...
# Processed 7110 tickets...
# Processed 7120 tickets...
# Processed 7130 tickets...
# Processed 7140 tickets...
# Processed 7150 tickets...
# Processed 7160 tickets...
# Processed 7170 tickets...
# Processed 7180 tickets...
# Processed 7190 tickets...
# Processed 7200 tickets...
# Processed 7210 tickets...
# Processed 7220 tickets...
# Processed 7230 tickets...
# Processed 7240 tickets...
# Processed 7250 tickets...
# Processed 7260 tickets...
# Processed 7270 tickets...
# Processed 7280 tickets...
# Processed 7290 tickets...
# Processed 7300 tickets...
# Processed 7310 tickets...
# Processed 7320 tickets...
# Processed 7330 tickets...
# Processed 7340 tickets...
# Processed 7350 tickets...
# Processed 7360 tickets...
# Processed 7370 tickets...
# Processed 7380 tickets...
# Processed 7390 tickets...
# Processed 7400 tickets...
# Processed 7410 tickets...
# Processed 7420 tickets...
# Processed 7430 tickets...
# Processed 7440 tickets...
# Processed 7450 tickets...
# Processed 7460 tickets...
# Processed 7470 tickets...
# Processed 7480 tickets...
# Processed 7490 tickets...
# Processed 7500 tickets...
# 💾 Saved checkpoint at 7500 tickets
# Processed 7510 tickets...
# Processed 7520 tickets...
# Processed 7530 tickets...
# Processed 7540 tickets...
# Processed 7550 tickets...
# Processed 7560 tickets...
# Processed 7570 tickets...
# Processed 7580 tickets...
# Processed 7590 tickets...
# Processed 7600 tickets...
# Processed 7610 tickets...
# Processed 7620 tickets...
# Processed 7630 tickets...
# Processed 7640 tickets...
# Processed 7650 tickets...
# Processed 7660 tickets...
# Processed 7670 tickets...
# Processed 7680 tickets...
# Processed 7690 tickets...
# Processed 7700 tickets...
# Processed 7710 tickets...
# Processed 7720 tickets...
# Processed 7730 tickets...
# Processed 7740 tickets...
# Processed 7750 tickets...
# Processed 7760 tickets...
# Processed 7770 tickets...
# Processed 7780 tickets...
# Processed 7790 tickets...
# Processed 7800 tickets...
# Processed 7810 tickets...
# Processed 7820 tickets...
# Processed 7830 tickets...
# Processed 7840 tickets...
# Processed 7850 tickets...
# Processed 7860 tickets...
# Processed 7870 tickets...
# Processed 7880 tickets...
# Processed 7890 tickets...
# Processed 7900 tickets...
# Processed 7910 tickets...
# Processed 7920 tickets...
# Processed 7930 tickets...
# Processed 7940 tickets...
# Processed 7950 tickets...
# Processed 7960 tickets...
# Processed 7970 tickets...
# Processed 7980 tickets...
# Processed 7990 tickets...
# Processed 8000 tickets...
# 💾 Saved checkpoint at 8000 tickets
# Processed 8010 tickets...
# Processed 8020 tickets...
# Processed 8030 tickets...
# Processed 8040 tickets...
# Processed 8050 tickets...
# Processed 8060 tickets...
# Processed 8070 tickets...
# Processed 8080 tickets...
# Processed 8090 tickets...
# Processed 8100 tickets...
# Processed 8110 tickets...
# Processed 8120 tickets...
# Processed 8130 tickets...
# Processed 8140 tickets...
# Processed 8150 tickets...
# Processed 8160 tickets...
# Processed 8170 tickets...
# Processed 8180 tickets...
# Processed 8190 tickets...
# Processed 8200 tickets...
# Processed 8210 tickets...
# Processed 8220 tickets...
# Processed 8230 tickets...
# Processed 8240 tickets...
# Processed 8250 tickets...
# Processed 8260 tickets...
# Processed 8270 tickets...
# Processed 8280 tickets...
# Processed 8290 tickets...
# Processed 8300 tickets...
# Processed 8310 tickets...
# Processed 8320 tickets...
# Processed 8330 tickets...
# Processed 8340 tickets...
# Processed 8350 tickets...
# Processed 8360 tickets...
# Processed 8370 tickets...
# Processed 8380 tickets...
# Processed 8390 tickets...
# Processed 8400 tickets...
# Processed 8410 tickets...
# Processed 8420 tickets...
# Processed 8430 tickets...
# Processed 8440 tickets...
# Processed 8450 tickets...
# Processed 8460 tickets...
# ✅ Done. Results saved to classified_tickets_results.csv

# %%
import pandas as pd
import numpy as np

# Load classified CSV
df = pd.read_csv("classified_tickets_results.csv")

# Extract top-1 labels
df["zs_top1"] = df["zero_shot_labels"].apply(lambda x: eval(x)[0])
df["fs_top1"] = df["few_shot_labels"].apply(lambda x: eval(x)[0])

# Extract top-1 scores
df["zs_score1"] = df["zero_shot_scores"].apply(lambda x: eval(x)[0])
df["fs_score1"] = df["few_shot_scores"].apply(lambda x: eval(x)[0])

# Compare agreement
agreement = (df["zs_top1"] == df["fs_top1"]).mean()
print(f"Top-1 label agreement between Zero-Shot and Few-Shot: {agreement*100:.2f}%")

# Average top-1 score (confidence)
zs_avg = df["zs_score1"].mean()
fs_avg = df["fs_score1"].mean()
print(f"Average Zero-Shot top-1 score: {zs_avg:.3f}")
print(f"Average Few-Shot top-1 score: {fs_avg:.3f}")

# Quick summary: which one seems more confident?
if zs_avg > fs_avg:
    print("Zero-Shot seems more confident on average.")
elif fs_avg > zs_avg:
    print("Few-Shot seems more confident on average.")
else:
    print("Both have similar confidence.")

# Optional: show 5 example differences
print("\nSample differences (first 5):")
diff = df[df["zs_top1"] != df["fs_top1"]].head(5)
for _, row in diff.iterrows():
    print(f"\nTicket: {row['ticket_text'][:50]}...")
    print(f"Zero-Shot: {row['zs_top1']} ({row['zs_score1']:.2f})")
    print(f"Few-Shot:  {row['fs_top1']} ({row['fs_score1']:.2f})")
# Out:
# Top-1 label agreement between Zero-Shot and Few-Shot: 17.62%
# Average Zero-Shot top-1 score: 0.810
# Average Few-Shot top-1 score: 0.889
# Few-Shot seems more confident on average.
#
# Sample differences (first 5):
#
# Ticket: Product setup - I'm having an issue with the {prod...
# Zero-Shot: Payment Issue (0.94)
# Few-Shot:  Login Issue (0.95)
#
# Ticket: Peripheral compatibility - I'm having an issue wit...
# Zero-Shot: Other (0.94)
# Few-Shot:  Login Issue (0.96)
#
# Ticket: Network problem - I'm facing a problem with my {pr...
# Zero-Shot: Bug (0.92)
# Few-Shot:  Login Issue (0.74)
#
# Ticket: Account access - I'm having an issue with the {pro...
# Zero-Shot: Bug (0.53)
# Few-Shot:  Login Issue (0.98)
#
# Ticket: Data loss - I'm having an issue with the {product_...
# Zero-Shot: Bug (0.90)
# Few-Shot:  Login Issue (0.92)

# %% [markdown]
# ***Overall Steps Followed***
#
# Load Dataset: Read the customer support tickets CSV containing ticket text and metadata.
#
# Define Categories: Set candidate labels for classification:
# ["Login Issue", "Payment Issue", "Bug", "Feature Request", "Other"]
#
# Zero-Shot Classification: Used joeddav/xlm-roberta-large-xnli to predict top-3 tags for each ticket.
#
# Few-Shot Classification: Designed small in-context prompts with examples and used the same model to predict top-3 tags.
#
# Save Results: Stored ticket ID, text, top-3 zero-shot/few-shot labels and scores in a CSV.
#
# Comparison (Quick Analysis): Evaluated agreement between zero-shot and few-shot top-1 labels and compared their average confidence scores.
#
#  **Quick Comparison Results**
#
# Top-1 label agreement: 17.62% → Zero-shot and Few-shot often predict different top tags.
#
# Average top-1 confidence:
#
# Zero-Shot: 0.810
#
# Few-Shot: 0.889
#
# Observation: Few-Shot is more confident on average and often chooses more contextually relevant tags.
#
# **Conclusion**
#
# Few-Shot classification appears more confident and context-aware than Zero-Shot.
#
# Zero-Shot sometimes predicts broader categories, while Few-Shot tends to focus on the most likely relevant tag.
#
# This demonstrates the benefit of prompt engineering / few-shot examples in improving classification quality even without fine-tuning.
